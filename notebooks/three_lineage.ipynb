# %%
# %cd /Users/Brett/Code/bricolage-dev/
from bricolage import lineage, threshold3, graph, analysis
from bricolage.analysis_ext import CausalFlowAnalyzer, Information, MutualInfoAnalyzer
# Out:
# /Users/Brett/Dropbox/Code/bricolage-dev

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sb
import numpy as np
import bisect
from IPython.display import Image

# %%
# %cd /Users/Brett/Code/bricolage-dev/
lin = pd.read_pickle('/Users/Brett/Dropbox/SimulationOutput/three/01-(a-and-not-c)-or-(b-and-c)/012/lineage.pickle')
# Out:
# /Users/Brett/Dropbox/Code/bricolage-dev

# %%
lin.plot(y=['F_50', 'CT_50'], subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x10be9c650>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x115e09310>], dtype=object)

# %%
fifties = ['C{}_50'.format(i) for i in range(1, 9)]
axes = lin.plot(y=['F_50'] + fifties, subplots=True)
fa = axes[0]
fa.set_ylim(0, 1)
fa.figure.set_figheight(10)
for a in axes[1:]:
    a.set_ylim(0, 3)
    a.set_yticks(range(4))

# %%
lin['CMAX_50'] = lin[fifties].max(axis=1)
lin['CMAXR'] = pd.rolling_mean(lin['CMAX_50'], 1000)
lin['FITR'] = pd.rolling_mean(lin['F_50'], 1000)

# %%
lin.plot(y=['F_50', 'CT_50', 'CMAX_50', 'FITR', 'CMAXR'], subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11d5778d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1190ea590>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11b5c0a90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11b731890>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11b7b4b10>], dtype=object)
